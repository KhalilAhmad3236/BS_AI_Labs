# %%
def welcome_message():
    print("Welcome to Python Programming Lab")
welcome_message()
# Out:
# Welcome to Python Programming Lab

# %%
def add_numbers(a, b):

    return a + b

# Call the function
result = add_numbers(5, 7)


print("The sum is:", result)
# Out:
# The sum is: 12

# %%
def functionA():
    print("Inside Function A")
    functionB()

def functionB():
    print("Inside Function B")


functionA()
# Out:
# Inside Function A
# Inside Function B

# %%
def greet(name="Student"):
    print("Hello", name)


greet()


greet("khalil")
# Out:
# Hello Student
# Hello khalil

# %%
x = 10

def my_function():

    print("global x:", x)

    y = 20
    print("Value of y:", y)

my_function()
# Out:
# global x: 10
# Value of y: 20

# %%
  def total_numbers(*numbers):
      total=sum(numbers)
      return total


print("Total numbers is : ",total_numbers(10, 20, 30, 40, 50))
# Out:
# Total numbers is :  150

# %%
def student_info(**data):
    for key, value in data.items():
        print(f"{key}: {value}")

student_info(name="khalil", age=21, major="ai", grade="A")
# Out:
# name: khalil
# age: 21
# major: ai
# grade: A

# %%
square = lambda x: x ** 2

print(square(10))
print(square(8))
# Out:
# 100
# 64

# %%
numbers = [1, 2, 3, 4, 5]

squares = list(map(lambda x: x*x, numbers))

print(squares)
# Out:
# [1, 4, 9, 16, 25]

# %%
marks = [45, 67, 82, 30, 90, 55]

greater_than_50 = list(filter(lambda x: x > 50, marks))

print(greater_than_50)
# Out:
# [67, 82, 90, 55]
